# %%
# # numpy bo karakany berkary w shekary datatkan .
# pandas bo barewabrdny datakan
import pandas as pd
import numpy as np

# %%
# lera datasetaka axaina naw variabley mydata.
mydata = pd.read_csv("/content/xAPI-Edu-Data.csv")

# %%
#show first 50 rows in data set
mydata.head(90)
# Out:
#    gender  NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0       M           KW       KuwaIT  lowerlevel    G-04         A    IT
# 1       M           KW       KuwaIT  lowerlevel    G-04         A    IT
# 2       M           KW       KuwaIT  lowerlevel    G-04         A    IT
# 3       M           KW       KuwaIT  lowerlevel    G-04         A    IT
# 4       M           KW       KuwaIT  lowerlevel    G-04         A    IT
# ..    ...          ...          ...         ...     ...       ...   ...
# 85      M           KW       KuwaIT  lowerlevel    G-02         B    IT
# 86      M  SaudiArabia  SaudiArabia  lowerlevel    G-02         B    IT
# 87      M           KW       KuwaIT  lowerlevel    G-02         B    IT
# 88      F           KW       KuwaIT  lowerlevel    G-02         B    IT
# 89      M           KW       KuwaIT  lowerlevel    G-02         B    IT
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %%
# data setaka daxata naw dataframek banawy mydata.
mydata = pd.read_csv("/content/xAPI-Edu-Data.csv")

# %%
# peshandany puxtayak zanyare datasetaka wak zhmaray column w row w datatype ....
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
mydata.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# peshandany histogramek bo zhmary column la data setaka.   30= weidth  40=high

# %%
import seaborn as sns

sns.boxplot(x="gender", y="raisedhands", data=mydata)

## boxplot drust dakat bo peshandany paywandy gendar w raiedhands
# Out:
# <Axes: xlabel='gender', ylabel='raisedhands'>

# %%
pd.crosstab(mydata['GradeID'], mydata['gender'])

## xshtayak drust dakat wa nishany dadat ka chand ner w me la ch polekn
# Out:
# gender      F   M
# Topic
# Arabic     16  43
# Biology    10  20
# Chemistry  12  12
# English    19  26
# French     30  35
# Geology    10  14
# History     8  11
# IT         32  63
# Math        5  16
# Quran       9  13
# Science    23  28
# Spanish     1  24

# %%
mydata['Topic'].value_counts()  # zhmaray qutabyan bo har babatek peshan dadat
# Out:
# Topic
# IT           95
# French       65
# Arabic       59
# Science      51
# English      45
# Biology      30
# Spanish      25
# Geology      24
# Chemistry    24
# Quran        22
# Math         21
# History      19
# Name: count, dtype: int64

# %%
sns.countplot(x="Topic", hue="gender", data=mydata) ##peshandany zhmaray ner w me la wanakan
# Out:
# <Axes: xlabel='Topic', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['Semester', 'gender'],
               columns=['StageID'], aggfunc=len)

## pivot_tablek drust dajat 2 index    aggfunc=len) ---> zhmaray rezakan bo har cominationek peshan dadat
# Out:
#                 AnnouncementsView                              Class  \
# StageID                HighSchool MiddleSchool lowerlevel HighSchool
# Semester gender
# F        F                     12           39         44         12
#          M                     11           71         68         11
# S        F                      3           43         34          3
#          M                      7           95         53          7
#
#                                         Discussion                          \
# StageID         MiddleSchool lowerlevel HighSchool MiddleSchool lowerlevel
# Semester gender
# F        F                39         44         12           39         44
#          M                71         68         11           71         68
# S        F                43         34          3           43         34
#          M                95         53          7           95         53
#
# ...

# %%
pd.pivot_table(mydata, 'Discussion', index=['Topic', 'gender'], columns=['StageID'])
## tekray mnaqasha krdn bo har babatek w ragazek peshan dadat bapey stageid dabashkrawa .
# Out:
# StageID           HighSchool  MiddleSchool  lowerlevel
# Topic     gender
# Arabic    F              NaN     42.375000   62.750000
#           M              NaN     39.600000   43.782609
# Biology   F              NaN     27.400000         NaN
#           M              NaN     56.850000         NaN
# Chemistry F              NaN     41.750000         NaN
#           M              NaN     36.250000         NaN
# English   F        67.857143     56.727273   20.000000
#           M        35.000000     32.411765   34.800000
# French    F        49.000000           NaN   28.241379
#           M              NaN           NaN   24.400000
# Geology   F              NaN     44.200000         NaN
#           M              NaN     59.000000         NaN
# History   F              NaN     67.750000   63.500000
#           M              NaN     74.250000   39.333333
# IT        F        70.000000     78.500000   33.333333
#           M        34.857143     46.800000   37.707317
# ...

# %%
mydata['raisedhands'].std() ## find standart division for the raisedhands student.
# Out:
# 30.779222582734224

# %%
mydata.hist(by='Semester',column = 'Topic') ## histogramek drust dakat bo jyawazy babatakn la bayney smestery 1 w 2.
# Out:
# array([<Axes: title={'center': 'F'}>, <Axes: title={'center': 'S'}>],
#       dtype=object)

# %%
mydata.hist(by='gender',column = 'Class')
# Out:
# array([<Axes: title={'center': 'F'}>, <Axes: title={'center': 'M'}>],
#       dtype=object)

# %%
mydata.hist(by='gender',column = 'Class')
# Out:
# array([<Axes: title={'center': 'F'}>, <Axes: title={'center': 'M'}>],
#       dtype=object)

# %%
mydata.hist(by='Relation',column = 'NationalITy', figsize=(10,30))
# Out:
# array([<Axes: title={'center': 'Father'}>,
#        <Axes: title={'center': 'Mum'}>], dtype=object)

# %%
sns.pairplot(mydata)
## functioneky seaborn'a bakardet bo drustkrdny torek la scatterplots w Histogram
## bo hamu zhmaray columakan lanaw datasetaka
